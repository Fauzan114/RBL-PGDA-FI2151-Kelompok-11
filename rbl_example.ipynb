# %% [markdown]
# # Analysis and Predictions for Indonesia Emas 2045

# %% [markdown]
# ## authors
#
# No | Name | ID | GitHub username | In charge activity
# :-: | :- | :-: | :- | :-
# 1 | Sekar Ayu Widhastri | 10222020 | [sekarwidhastri](https://github.com/sekarwidhastri) | YouTube presentation video
# 2 | Naufaldo Indra Pratama | 10222026 | [aldo02032004](https://github.com/aldo02032004) | Slide on OSF
# 3 | Huzain Hadi Purnomo | 10222045 | [HuzainHadi](https://github.com/HuzainHadi) | Notebook finalization
# 4 | Fauzan Akbar Ramdhan | 10222114 | [Fauzan114](https://github.com/Fauzan114) | Discussion on GitHub issues

# %% [markdown]
# ## abstract
# Indonesia Emas 2045 is often touted by the current government. This paper aims to analyze the prediction of the realization of Indonesia Emas 2045 by visualizing several data parameters such as HDI, GDP, and Poverty Rate which will also be compared with several other countries. Data collection was carried out by taking sources from the internet that are guaranteed and data visualization was carried out using scatter plot graphics and linear regression. The results of the analysis answered that 2 out of 3 parameters stated optimism for the occurrence of Indonesia Emas 2045, although the method used was very simple and did not take into account other variables.

# %% [markdown]
# ## background
# This paper aims to:
# 1. Visualize several data parameters from the targets of Indonesia Emas 2045 by comparing them with those of other countries,
# 2. Determine whether Indonesia Emas 2045 is on track to achieve its goals by evaluating relevant parameters,
# 3. Assess the level of success in realizing Indonesia Emas 2045, and
# 4. Predict future prospects regarding Indonesia Emas 2045.
#
# Indonesia Emas 2045 is often discussed, and there is skepticism about whether the vision for Indonesia in 2045, which is expected to represent the nation’s peak of prosperity, will be realized. Such doubts and concerns need to be addressed and mitigated by examining key factors through data-based visualizations, evaluations, and analyses that can help materialize Indonesia Emas 2045. By presenting such analyses, a more informed and prudent approach can be adopted by all Indonesian citizens regarding the feasibility of achieving Indonesia Emas 2045.
#
# This paper is inspired by various external factors that have been discussed in scientific papers, news, and everyday societal contexts in Indonesia. The paper *Generasi Muda Indonesia Emas 2045*, written by a student from Universitas Katolik Santo Thomas Medan, highlights the importance of competent human resources as a key factor in realizing Indonesia Emas 2045[[1](https://www.scribd.com/document/501133776/Makalah-Generasi-Muda-Indonesia-Emas)]. Additionally, *Current Economic Conditions in Myanmar and Options for Sustainable Growth,* written by a professor from Tufts University[[2](https://www.bu.edu/eci/files/2019/06/03-04myanmar.pdf)], is used as a comparative reference to predict the achievement of Indonesia Emas 2045. The paper *US Economic Growth in the Gilded Age,* authored by Alexander J. Field[[3](https://www.sciencedirect.com/science/article/abs/pii/S0164070407001322)], serves as another comparative study. Lastly, a paper by Lynge Nielsen[[4](https://www.imf.org/external/pubs/ft/wp/2011/wp1131.pdf?utm_source=chatgpt.com)] is used as a reference for classifying developed and developing countries.

# %% [markdown]
# ## method
# Flowchart
#
# ![rbl_pgda.jpg](attachment:rbl_pgda.jpg)

# %% [markdown]
# **Code**
# 1. HDI          : [code](https://gist.github.com/aldo02032004/ea6c51c20f376e80d746011f045e6182)
# 2. GDP          : [code](https://gist.github.com/sekarwidhastri/6d48b831354be25fcfeb5a3989b0f04e)
# 3. Poverty Rate : [code](https://colab.research.google.com/drive/10SxDsuCYN7ER6bQ-KBwUxlkmTcTvyMwM?usp=sharing)

# %% [markdown]
# ## results and dicussion
#
# ![hdi.png](attachment:hdi.png)
#
# ![gdp.png](attachment:gdp.png)
#
# ![poverty_rate.png](attachment:poverty_rate.png)
#
# Based on the existing visualization code, two out of three parameters indicate predictions that align closely with the characteristics of developed countries. The poverty rate and GDP parameters show optimistic results for Indonesia, approaching the characteristics of developed nations such as Switzerland and the United States. However, the HDI parameter presents less promising results, suggesting a less favorable outlook for Indonesia to achieve developed country status.
#
# From this analysis, it can be optimistically stated that Indonesia Emas 2045 appears to be reasonably achievable. Nonetheless, this assessment does not yet account for other potential factors that may significantly influence the realization of Indonesia Emas 2045. This preliminary analysis requires further review, both in terms of statistical modeling—utilizing more complex methods with higher accuracy—and by incorporating a broader range of factors that could have a substantial impact on achieving the vision.

# %% [markdown]
# ## conclusion
# Two out of the three parameters—GDP and Poverty Rate—present optimistic predictions for the realization of Indonesia Emas 2045, while the HDI parameter remains a pessimistic indicator. This simple analysis cannot serve as an absolute reference to conclude that Indonesia Emas 2045 is certain to occur. However, this basic representation can serve as a small yet significant first step for the Indonesian people to intensify efforts toward realizing this shared grand vision of Indonesia Emas 2045.
#
# Regardless of the accuracy of predictive analyses, the ultimate outcome of this nation’s progress will ultimately depend on the efforts of its youth, government, and citizens. This shared responsibility highlights the critical role of collective action in achieving Indonesia Emas 2045.

# %% [markdown]
# ## references
# [1] Author Unknown, *Makalah Generasi Muda Indonesia Emas 2045*. Universitas Katolik Santo Thomas Medan. [Online]. Available: https://id.scribd.com/document/501133776/Makalah-Generasi-Muda-Indonesia-Emas. [Accessed: Dec. 24, 2024].
#
# [2] Author Unknown, *Current Economic Conditions in Myanmar and Options for Sustainable Growth*. Tufts University. [Online]. Available: https://www.bu.edu/eci/files/2019/06/03-04myanmar.pdf. [Accessed: Dec. 24, 2024].
#
# [3] A. J. Field, "US Economic Growth in the Gilded Age," *Explorations in Economic History*, vol. 45, no. 4, pp. 540-553, Oct. 2007. [Online]. Available: https://www.sciencedirect.com/science/article/abs/pii/S0164070407001322. [Accessed: Dec. 24, 2024].
#
# [4] L. Nielsen, *Classifications of Countries Based on Their Level of Development: How it is Done and How it Could Be Done*. International Monetary Fund, WP/11/31, Feb. 2011. [Online]. Available: https://www.imf.org/external/pubs/ft/wp/2011/wp1131.pdf?utm_source=chatgpt.com. [Accessed: Dec. 24, 2024].
